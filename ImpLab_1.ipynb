# %%
import cv2
print(cv2.__version__)
# Out:
# 5.0.0

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-a0a3a984-dd3d-4796-817f-f9e49332105c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0a3a984-dd3d-4796-817f-f9e49332105c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow
from IPython.display import Video

# %%
# Read image
image = cv2.imread("wallpaper.jpg")

# Display image
print("Original Image")
cv2_imshow(image)

# Write image
cv2.imwrite("saved_image.jpg", image)

print("Image saved successfully.")
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=1280x906>
# Image saved successfully.

# %%
cv2.imwrite("wallpaper.png", image)
cv2.imwrite("wallpaper.tiff", image)
cv2.imwrite("wallpaper.bmp", image)

print("Image converted to PNG, TIFF, and BMP formats.")
# Out:
# Image converted to PNG, TIFF, and BMP formats.

# %%
# Resize image
resized = cv2.resize(image, (400, 300))

print("Resized Image")
cv2_imshow(resized)

# Save resized image
cv2.imwrite("resized_image.jpg", resized)

print("Image resized successfully.")
# Out:
# Resized Image
# <PIL.Image.Image image mode=RGB size=400x300>
# Image resized successfully.

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

print("Grayscale Image")
cv2_imshow(gray)

cv2.imwrite("gray_image.jpg", gray)

print("Grayscale image saved.")
# Out:
# Grayscale Image
# <PIL.Image.Image image mode=L size=1280x906>
# Grayscale image saved.

# %%
print("Displaying Video")

Video("video.mp4", embed=True)
# Out:
# Displaying Video
# <video controls  >
#  <source src="....mp4" type="None">
#  Your browser does not support the video tag.
#  </video>

# %%
cap = cv2.VideoCapture("video.mp4")

count = 0

while True:
    ret, frame = cap.read()

    if not ret:
        break

    filename = f"frame_{count}.jpg"

    cv2.imwrite(filename, frame)

    count += 1

cap.release()

print("Total Frames Extracted:", count)
# Out:
# Total Frames Extracted: 0

# %%
frame = cv2.imread("wallpaper.jpg")

print("First Extracted Frame")

cv2_imshow(frame)
# Out:
# First Extracted Frame
# <PIL.Image.Image image mode=RGB size=1280x906>
